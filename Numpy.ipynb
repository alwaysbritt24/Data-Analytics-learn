# %% [markdown]
# <a href="https://colab.research.google.com/github/alwaysbritt24/Data-Analytics-learn/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NumPY

# %%
import random

salary_list = [random.randint(50000, 100000) for _ in range(1_000_000)]

salary_list
# Out:
# [71407,
#  68577,
#  78187,
#  63866,
#  82369,
#  85931,
#  84309,
#  74881,
#  64055,
#  98649,
#  95861,
#  71785,
#  94436,
#  91591,
#  57538,
#  96725,
#  87728,
#  82939,
#  97661,
#  57385,
#  54659,
#  68958,
#  75981,
#  59658,
#  75189,
#  98543,
#  91641,
#  56227,
#  99131,
#  63494,
#  90231,
#  54996,
#  76886,
#  83769,
#  76345,
#  80679,
#  83936,
#  74858,
#  76177,
#  98402,
#  79215,
#  60730,
#  91145,
#  67105,
#  53725,
#  61991,
#  89697,
#  74898,
#  93623,
#  99906,
#  71346,
#  95497,
#  88701,
#  96819,
#  96220,
#  88987,
#  68810,
#  97566,
#  66452,
#  77673,
#  75509,
#  78149,
#  68234,
#  51700,
#  72894,
#  58310,
#  60886,
#  89951,
#  98764,
#  77473,
#  51238,
#  55897,
#  51043,
#  81739,
#  78440,
#  87030,
#  97644,
#  55611,
#  88790,
#  83772,
#  58909,
#  85455,
#  94462,
#  89875,
#  61841,
#  74543,
#  57031,
#  80160,
#  96909,
#  74079,
#  59234,
#  91619,
#  94948,
#  95600,
#  68377,
#  98634,
#  69930,
#  81524,
#  97061,
#  59846,
# ...

# %%
import statistics

# %%
# %%timeit

statistics.mean(salary_list)
# Out:
# 242 ms ± 10.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %%timeit
np.median(salary_list)
# Out:
# 83 ms ± 22.2 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
my_array = np.array([1,2,3,4])

# %%
my_array.mean()
# Out:
# np.float64(2.5)

# %%
#Job Titles
job_titles = np.arrya = (['Data Analyst', 'Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'AI Engineer'])

#Base Salaries
base_salaries = np.array([60000, 80000, 75000, 90000, np.nan])

#bonus rate
bonus_rate = np.array([0.05, 0.1, 0.08, 0.12, np.nan])

# %%
total_salaries = base_salaries  *(1 + bonus_rate)

total_salaries
# Out:
# array([ 63000.,  88000.,  81000., 100800.,     nan])

# %%
np.nanmean(total_salaries)
# Out:
# np.float64(83200.0)
